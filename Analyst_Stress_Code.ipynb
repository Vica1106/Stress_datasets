# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import requests
from matplotlib.ticker import MaxNLocator

# %%
# To import our data
df = pd.read_csv('modified_stress.tsv', sep='\t')

# %%
#sort the dataset by pvalue and only get a sub dataset of dataset's pvalue < 0.01
df = df[df['pvalue'] < 0.01].sort_values('pvalue')

# %% [markdown]
# Steps to get url for everyone

# %%
txt_df = pd.read_csv("conv.txt", sep="\t")

# %%
merged_df = pd.merge(df, txt_df, left_on='Geneid_Name', right_on='From', how='right')

# %%
merged_df= merged_df[["Geneid_Name", "log2FoldChange", "pvalue", "padj", "To", "Gene Name"]]

# %%
# Renaming the columns in the merged DataFrame
merged_df.rename(columns={'Gene Name': 'Full Name', 'To': 'URL ID'}, inplace=True)

# %%
base_url = "https://davidbioinformatics.nih.gov/api.jsp?type=ENTREZ_GENE_ID&ids={ids}&tool=geneReport"
merged_df['URL'] = merged_df['URL ID'].apply(lambda x: base_url.format(ids=x))
# Displaying the DataFrame to verify the URLs
merged_df = merged_df[['Geneid_Name', 'log2FoldChange', 'pvalue', 'padj', 'Full Name', 'URL']]

# %%
merged_df.to_csv('./subdataset_stress/Stress_lessthan0.01_conbineurl.tsv', sep='\t', index=False)

# %%
df= merged_df

# %% [markdown]
# Copy the data from David Website and paste to here. in this formate

# %% [markdown]
# text=""" data """

# %%
df = pd.read_csv('./Stress_datasets/Stress_lessthan0.01_conbineurl.tsv', sep='\t')

# %%
text = """

Zinc-finger & Zinc-finger
predicted gene 14308(Gm14308)
ring finger protein 185(Rnf185)
lysine (K)-specific demethylase 4C(Kdm4c)
myosin IXb(Myo9b)
ankyrin repeat and zinc finger domain containing 1(Ankzf1)
predicted gene 15446(Gm15446)
zinc finger protein 87(Zfp87)
zinc finger protein 740(Zfp740)
PAN3 poly(A) specific ribonuclease subunit(Pan3)
nuclear receptor subfamily 4, group A, member 1(Nr4a1)
menage a trois 1(Mnat1)
mex3 RNA binding family member C(Mex3c)
ras responsive element binding protein 1(Rreb1)
RNA binding motif protein 4B(Rbm4b)
ring finger protein (C3H2C3 type) 6(Rnf6)
zinc finger and BTB domain containing 11(Zbtb11)
B cell leukemia/lymphoma 6(Bcl6)
zinc finger CCCH type containing 3(Zc3h3)
THAP domain containing, apoptosis associated protein 1(Thap1)
zinc finger protein 692(Zfp692)
PHD finger protein 21A(Phf21a)
zinc finger protein 27(Zfp27)
TRAF type zinc finger domain containing 1(Trafd1)
topoisomerase I binding, arginine/serine-rich(Topors)
zinc finger and BTB domain containing 41(Zbtb41)
nuclear receptor subfamily 1, group D, member 2(Nr1d2)
zinc finger protein 641(Zfp641)
zinc finger, MYM-type 3(Zmym3)
tripartite motif-containing 32(Trim32)
AE binding protein 2(Aebp2)
zinc finger protein 106(Zfp106)
tRNA methyltransferase 1(Trmt1)
zinc finger protein 422(Zfp422)
fused in sarcoma(Fus)
zinc finger, CCHC domain containing 13(Zcchc13)
DAZ interacting protein 1-like(Dzip1l)
zinc finger protein 719(Zfp719)
zinc finger protein 57(Zfp57)
small ArfGAP 1(Smap1)
protein kinase C, beta(Prkcb)
tripartite motif-containing 72(Trim72)
myeloid zinc finger 1(Mzf1)
zinc finger protein 14(Zfp14)
interleukin 17 receptor D(Il17rd)
zinc finger protein 68(Zfp68)
ubiquitin specific peptidase 49(Usp49)
nuclear receptor subfamily 6, group A, member 1(Nr6a1)
ring finger protein 31(Rnf31)
zinc finger protein 180(Zfp180)
early growth response 1(Egr1)
muscleblind like splicing factor 2(Mbnl2)
early growth response 2(Egr2)
zinc finger, FYVE domain containing 28(Zfyve28)
early growth response 4(Egr4)
TCDD-inducible poly(ADP-ribose) polymerase(Tiparp)
zinc finger protein 78(Zfp78)
lysine (K)-specific methyltransferase 2D(Kmt2d)
Gem-interacting protein(Gmip)
L3MBTL1 histone methyl-lysine binding protein(L3mbtl1)
zinc finger protein 408(Zfp408)
chromosome alignment maintaining phosphoprotein 1(Champ1)
ring finger protein 2(Rnf2)
ring finger protein 4(Rnf4)
zinc finger protein 605(Zfp605)
RIKEN cDNA A430033K04 gene(A430033K04Rik)
integrator complex subunit 12(Ints12)
mbt domain containing 1(Mbtd1)
zinc fingers and homeoboxes 1(Zhx1)
autoimmune regulator(Aire)
G patch domain containing 8(Gpatch8)
SLX1 structure-specific endonuclease subunit homolog B (S. cerevisiae)(Slx1b)
E4F transcription factor 1(E4f1)
zinc finger protein 868(Zfp868)
WD repeat and FYVE domain containing 1(Wdfy1)
DNA methyltransferase 3A(Dnmt3a)
macrophage erythroblast attacher(Maea)
zinc finger protein 110(Zfp110)
zinc finger homeobox 2(Zfhx2)
ariadne RBR E3 ubiquitin protein ligase 1(Arih1)

top
Zinc-finger

top
Zinc-finger


Please cite DAVID within any publication that makes use of any methods inspired by DAVID.
Terms of Service

"""

# %% [markdown]
# Since there are so many text and we only care about the gene name inside (), we run the following codes.

# %%
gene_names = re.findall(r'\(([^()]+)\)$', text, re.MULTILINE)

df1 = pd.DataFrame(gene_names, columns=['Gene_Name'])

# %%
# we get a new data set that contains 308 gene names (match with our original datasets)
df1
# Out:
#    Gene_Name
# 0    Gm14308
# 1     Rnf185
# 2      Kdm4c
# 3      Myo9b
# 4     Ankzf1
# ..       ...
# 74    Dnmt3a
# 75      Maea
# 76    Zfp110
# 77     Zfhx2
# 78     Arih1
#
# [79 rows x 1 columns]

# %%
#put two data set together, double check we have the correct amount of gene names. 
df_f3 = df1.merge(df, left_on= "Gene_Name", right_on="Geneid_Name")

# %%
df_f3 = df_f3.drop(columns=["Geneid_Name"])
df_f3.to_csv('./Stress_datasets/Zinc-finger_UP_KW_DOMAIN.tsv', sep='\t', index=False)

# %%
df_f3 = df_f3.sort_values("padj")
df3_top_10_padj = df_f3.head(10)
df3_top_10_padj.to_csv('./Stress_datasets/padj10_Zinc-finger_UP_KW_DOMAIN.tsv', sep='\t', index=False)
df3_top_10_padj.iloc[:, :-1]
# Out:
#    Gene_Name  log2FoldChange    pvalue      padj  \
# 62      Rnf4        0.105037  0.000001  0.003113
# 9      Nr4a1        0.432547  0.000004  0.004693
# 13     Rbm4b       -0.176596  0.000019  0.011957
# 51      Egr2        0.599209  0.000017  0.011957
# 17     Zc3h3       -0.126247  0.000024  0.012342
# 48    Zfp180        0.089793  0.000057  0.017591
# 12     Rreb1       -0.316284  0.000081  0.019619
# 57      Gmip       -0.200405  0.000173  0.025870
# 41      Mzf1       -0.130156  0.000219  0.029336
# 15    Zbtb11        0.117283  0.000254  0.032410
#
#                                                  Full Name
# 62                             ring finger protein 4(Rnf4)
# 9   nuclear receptor subfamily 4, group A, member 1(Nr4a1)
# 13                     RNA binding motif protein 4B(Rbm4b)
# 51                           early growth response 2(Egr2)
# 17               zinc finger CCCH type containing 3(Zc3h3)
# 48                         zinc finger protein 180(Zfp180)
# ...

# %%
df_f3 = df_f3.reindex(df_f3["log2FoldChange"].abs().sort_values().index)
df3_top_10_log = df_f3.head(10)
df3_top_10_padj.to_csv('./Stress_datasets/log2change10_Zinc-finger_UP_KW_DOMAIN.tsv', sep='\t', index=False)
df3_top_10_log.iloc[:, :-1]
# Out:
#    Gene_Name  log2FoldChange    pvalue      padj  \
# 30    Zfp106        0.058364  0.006442  0.141674
# 28    Trim32        0.060731  0.006406  0.141198
# 75      Maea        0.064300  0.005819  0.135611
# 1     Rnf185        0.067733  0.005327  0.130571
# 60    Champ1        0.067905  0.004194  0.115972
# 7     Zfp740       -0.070758  0.009886  0.167013
# 20    Phf21a       -0.073670  0.000836  0.057312
# 32    Zfp422        0.077310  0.003778  0.113241
# 78     Arih1        0.078948  0.000439  0.042951
# 21     Zfp27        0.080620  0.006388  0.141131
#
#                                                     Full Name
# 30                            zinc finger protein 106(Zfp106)
# 28                     tripartite motif-containing 32(Trim32)
# 75                     macrophage erythroblast attacher(Maea)
# 1                             ring finger protein 185(Rnf185)
# 60  chromosome alignment maintaining phosphoprotein 1(Champ1)
# ...

# %%
table11 = df3_top_10_padj
table12 = df3_top_10_log
table11
# Out:
#     Gene_Name  log2FoldChange        pvalue      padj  \
# 133       Kcp       -0.458202  4.520465e-07  0.001810
# 108     Nup50        0.080698  2.393809e-06  0.004077
# 178     Hdac7       -0.256441  1.452801e-05  0.011835
# 111      Hps1       -0.283047  2.127643e-05  0.011957
# 154      Egr2        0.599209  1.688508e-05  0.011957
# 80      Rbm4b       -0.176596  1.905720e-05  0.011957
# 12     Ccdc62       -0.292479  1.570267e-05  0.011957
# 171     Zc3h3       -0.126247  2.437520e-05  0.012342
# 68     Tgoln1        0.126464  2.814590e-05  0.013522
# 62      Anxa9       -0.324713  2.947911e-05  0.013808
#
#                                                               Full Name  \
# 133                                    kielin/chordin-like protein(Kcp)
# 108                                               nucleoporin 50(Nup50)
# 178                                        histone deacetylase 7(Hdac7)
# 111  HPS1, biogenesis of lysosomal organelles complex 3 subunit 1(Hps1)
# ...

# %%
table21 = df3_top_10_padj
table22 = df3_top_10_log
table21
# Out:
#     Gene_Name  log2FoldChange        pvalue      padj  \
# 128      Sbsn       -0.344124  8.469662e-08  0.000793
# 25        Kcp       -0.458202  4.520465e-07  0.001810
# 34    Ccdc142       -0.258381  7.169923e-07  0.001919
# 13     Ccdc62       -0.292479  1.570267e-05  0.011957
# 84       Pes1        0.109793  4.461248e-05  0.016389
# 96       Prc1       -0.246946  5.493748e-05  0.017591
# 78     Ushbp1       -0.303624  5.318076e-05  0.017591
# 18      Cdc5l        0.147299  7.186212e-05  0.018948
# 28       Nudc        0.094075  7.281336e-05  0.018948
# 19      Whamm       -0.109436  7.541742e-05  0.019095
#
#                                                                               Full Name  \
# 128                                                                    suprabasin(Sbsn)
# 25                                                     kielin/chordin-like protein(Kcp)
# 34                                           coiled-coil domain containing 142(Ccdc142)
# ...

# %%
table31 = df3_top_10_padj
table32 = df3_top_10_log
table31
# Out:
#    Gene_Name  log2FoldChange    pvalue      padj  \
# 62      Rnf4        0.105037  0.000001  0.003113
# 9      Nr4a1        0.432547  0.000004  0.004693
# 13     Rbm4b       -0.176596  0.000019  0.011957
# 51      Egr2        0.599209  0.000017  0.011957
# 17     Zc3h3       -0.126247  0.000024  0.012342
# 48    Zfp180        0.089793  0.000057  0.017591
# 12     Rreb1       -0.316284  0.000081  0.019619
# 57      Gmip       -0.200405  0.000173  0.025870
# 41      Mzf1       -0.130156  0.000219  0.029336
# 15    Zbtb11        0.117283  0.000254  0.032410
#
#                                                  Full Name  \
# 62                             ring finger protein 4(Rnf4)
# 9   nuclear receptor subfamily 4, group A, member 1(Nr4a1)
# 13                     RNA binding motif protein 4B(Rbm4b)
# 51                           early growth response 2(Egr2)
# 17               zinc finger CCCH type containing 3(Zc3h3)
# 48                         zinc finger protein 180(Zfp180)
# ...

# %%
table41 = df3_top_10_padj
table42 = df3_top_10_log
table41
# Out:
#    Gene_Name  log2FoldChange        pvalue      padj  \
# 59     Xrcc3       -0.289597  6.220295e-07  0.001919
# 73      Wee1        0.174605  2.256439e-06  0.004077
# 40       Aqr        0.106255  2.069092e-05  0.011957
# 23    Mapk12       -0.284827  7.077575e-05  0.018948
# 34     Vars2       -0.119052  1.220645e-04  0.022204
# 31     Mov10       -0.225631  1.318901e-04  0.022969
# 77      Pkn3       -0.379728  1.533037e-04  0.024171
# 49     Scyl2        0.086038  2.761952e-04  0.034045
# 69   Caprin1        0.092796  3.450314e-04  0.037804
# 27      Rrm1        0.113986  4.019901e-04  0.040933
#
#                                                                         Full Name  \
# 59  X-ray repair complementing defective repair in Chinese hamster cells 3(Xrcc3)
# 73                                               WEE 1 homolog 1 (S. pombe)(Wee1)
# 40                                                                  aquarius(Aqr)
# ...

# %%
table51 = df3_top_10_padj
table52 = df3_top_10_log
table51
# Out:
#    Gene_Name  log2FoldChange        pvalue      padj  \
# 64     Xrcc3       -0.289597  6.220295e-07  0.001919
# 77      Wee1        0.174605  2.256439e-06  0.004077
# 44       Aqr        0.106255  2.069092e-05  0.011957
# 27    Mapk12       -0.284827  7.077575e-05  0.018948
# 37     Vars2       -0.119052  1.220645e-04  0.022204
# 34     Mov10       -0.225631  1.318901e-04  0.022969
# 82      Pkn3       -0.379728  1.533037e-04  0.024171
# 73   Caprin1        0.092796  3.450314e-04  0.037804
# 31      Rrm1        0.113986  4.019901e-04  0.040933
# 19      Sik1        0.321993  4.326781e-04  0.042667
#
#                                                                         Full Name  \
# 64  X-ray repair complementing defective repair in Chinese hamster cells 3(Xrcc3)
# 77                                               WEE 1 homolog 1 (S. pombe)(Wee1)
# 44                                                                  aquarius(Aqr)
# ...

# %%
table61 = df3_top_10_padj
table62 = df3_top_10_log
table61
# Out:
#    Gene_Name  log2FoldChange    pvalue      padj  \
# 15      Wee1        0.174605  0.000002  0.004077
# 1     Mapk12       -0.284827  0.000071  0.018948
# 19      Sik1        0.321993  0.000433  0.042667
# 18     Idh3a        0.093183  0.001569  0.075165
# 13      Tppp        0.109954  0.001609  0.075914
# 4    Prps1l3        0.157329  0.002864  0.100812
# 10     Dyrk3        0.152120  0.002976  0.101448
# 8      Pdcd6        0.078754  0.003252  0.106626
# 20     Adcy2        0.082123  0.004005  0.114123
# 6     Plscr3       -0.130292  0.004273  0.116878
#
#                                                               Full Name  \
# 15                                     WEE 1 homolog 1 (S. pombe)(Wee1)
# 1                           mitogen-activated protein kinase 12(Mapk12)
# 19                                        salt inducible kinase 1(Sik1)
# 18                       isocitrate dehydrogenase 3 (NAD+) alpha(Idh3a)
# ...

# %%
tables = [table11, table21]
merged_df = pd.concat(tables)

merged_df.shape
# Out:
# (20, 6)

# %%
merged_df.to_csv('./Stress_datasets/merged_padj_Top10_UP_KW_DOMAIN.tsv', sep='\t', index=False)

# %%
gene_counts = merged_df['Gene_Name'].value_counts().reset_index()
gene_counts.columns = ['Gene_Name', 'Count']
gene_pvalues = merged_df.groupby('Gene_Name')['padj'].mean().reset_index()
gene_counts = pd.merge(gene_counts, gene_pvalues, on='Gene_Name')

gene_urls = merged_df.groupby('Gene_Name')['URL'].first().reset_index() 
gene_counts = pd.merge(gene_counts, gene_urls, on='Gene_Name', how='left')
# Filter genes with count > 1
gene_counts_filtered = gene_counts[gene_counts['Count'] > 1]
gene_counts_filtered.to_csv('./Stress_datasets/TableCount_padj_UP_KW_DOMAIN.tsv', sep='\t', index=False)
gene_counts_filtered
# Out:
#   Gene_Name  Count      padj  \
# 0       Kcp      2  0.001810
# 1    Ccdc62      2  0.011957
#
#                                                                                           URL
# 0  https://davidbioinformatics.nih.gov/api.jsp?type=ENTREZ_GENE_ID&ids=333088&tool=geneReport
# 1  https://davidbioinformatics.nih.gov/api.jsp?type=ENTREZ_GENE_ID&ids=208908&tool=geneReport

# %%
# Normalize and set up color mapping
norm = plt.Normalize(gene_counts_filtered['padj'].min(), gene_counts_filtered['padj'].max())
colors = cm.viridis(norm(gene_counts_filtered['padj']))

# Plot the bar chart with color mapping
fig, ax = plt.subplots(figsize=(5, 6))  # Explicitly create figure and axes
bars = ax.bar(gene_counts_filtered['Gene_Name'], gene_counts_filtered['Count'], color=colors)

# Set labels and title
ax.set_xlabel('Gene Name')
ax.set_ylabel('Count')
ax.set_title('Gene Counts with Padj-value-Based Coloring (Count > 1)')
ax.set_xticks(range(len(gene_counts_filtered['Gene_Name'])))
ax.set_xticklabels(gene_counts_filtered['Gene_Name'], rotation=45, ha='right')

# Set y-axis to only have integer values
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

max_count = gene_counts_filtered['Count'].max()
ax.set_ylim(0, max_count + 0.5)

# Add a colorbar for reference
sm = cm.ScalarMappable(cmap='viridis', norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.2)
cbar.set_label('Adjusted P-value (Padj)')  # Changed label to be more descriptive

# Annotate p-values on bars
for i, pval in enumerate(gene_counts_filtered['padj']):
    ax.text(i, gene_counts_filtered['Count'].iloc[i] + 0.1, f'{pval:.2e}', ha='center', fontsize=8)

plt.tight_layout()
plt.show()

# %%
tables = [table12, table22]
merged_df = pd.concat(tables)

merged_df.shape
# Out:
# (20, 6)

# %%
merged_df.to_csv('./Stress_datasets/merged_log2FoldChange_Top10_UP_KW_DOMAIN.tsv', sep='\t', index=False)

# %%
gene_counts = merged_df['Gene_Name'].value_counts().reset_index()
gene_counts.columns = ['Gene_Name', 'Count']
gene_pvalues = merged_df.groupby('Gene_Name')['log2FoldChange'].mean().reset_index()
gene_counts = pd.merge(gene_counts, gene_pvalues, on='Gene_Name')

gene_urls = merged_df.groupby('Gene_Name')['URL'].first().reset_index() 
gene_counts = pd.merge(gene_counts, gene_urls, on='Gene_Name', how='left')
# Filter genes with count > 1
gene_counts_filtered = gene_counts[gene_counts['Count'] > 1]
gene_counts_filtered.to_csv('./Stress_datasets/TableCount_log2FoldChange_UP_KW_DOMAIN.tsv', sep='\t', index=False)
gene_counts_filtered
# Out:
#   Gene_Name  Count  log2FoldChange  \
# 0     Strn3      2        0.066180
# 1    Trim32      2        0.060731
#
#                                                                                          URL
# 0  https://davidbioinformatics.nih.gov/api.jsp?type=ENTREZ_GENE_ID&ids=94186&tool=geneReport
# 1  https://davidbioinformatics.nih.gov/api.jsp?type=ENTREZ_GENE_ID&ids=69807&tool=geneReport

# %%
abs_log2FoldChange = gene_counts_filtered['log2FoldChange'].abs()

# Normalize and set up color mapping based on absolute log2FoldChange values
norm = plt.Normalize(abs_log2FoldChange.min(), abs_log2FoldChange.max())
colors = cm.viridis(norm(abs_log2FoldChange))

# Plot the bar chart with color mapping
fig, ax = plt.subplots(figsize=(10, 6))  # Explicitly create figure and axes
bars = ax.bar(gene_counts_filtered['Gene_Name'], gene_counts_filtered['Count'], color=colors)

# Set labels and title
ax.set_xlabel('Gene Name')
ax.set_ylabel('Count')
ax.set_title('Gene Counts with log2FoldChange-Based Coloring (Count > 1)')
ax.set_xticks(range(len(gene_counts_filtered['Gene_Name'])))
ax.set_xticklabels(gene_counts_filtered['Gene_Name'], rotation=45, ha='right')
max_count = gene_counts_filtered['Count'].max()
ax.set_ylim(0, max_count + 0.5) 

# Ensure y-axis only shows integer values
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

# Add a colorbar for reference
sm = cm.ScalarMappable(cmap='viridis', norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.2)
cbar.set_label('Absolute Log2FoldChange Value')  # Changed label to be more descriptive

# Annotate p-values on bars
for i, pval in enumerate(gene_counts_filtered['log2FoldChange']):
    ax.text(i, gene_counts_filtered['Count'].iloc[i] + 0.1, f'{pval:.2e}', ha='center', fontsize=8)

plt.tight_layout()
plt.show()

# %%
path1="Stress_datasets/UP_SEQ_FEATURE/top10_COMPBIAS_Polar_residues/padj10_COMPBIAS_Polar_residues_UP_SEQ_FEATURE.tsv"
path2="Stress_datasets/UP_SEQ_FEATURE/top10_COMPBIAS_Polar_residues/log2change10_COMPBIAS_Polar_residues_UP_SEQ_FEATURE.tsv"

# %%
table11 = pd.read_csv(path1, sep='\t')
table12 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/UP_SEQ_FEATURE/top10_Region_disordered/padj10_REGION:Disordered_UP_SEQ_FEATURE.tsv"
path2="Stress_datasets/UP_SEQ_FEATURE/top10_Region_disordered/log2change10_REGION:Disordered_UP_SEQ_FEATURE.tsv"
table21 = pd.read_csv(path1, sep='\t')
table22 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/UP_KW_PTM/top10_Acetylation/padj10_Acetylation_UP_KW_PTM.tsv"
path2="Stress_datasets/UP_KW_PTM/top10_Acetylation/log2change10_Acetylation_UP_KW_PTM.tsv"
table31 = pd.read_csv(path1, sep='\t')
table32 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/UP_KW_PTM/top10_Phosphoprotein/padj10_Phosphoprotein_UP_KW_PTM.tsv"
path2="Stress_datasets/UP_KW_PTM/top10_Phosphoprotein/log2change10_Phosphoprotein_UP_KW_PTM.tsv"
table41 = pd.read_csv(path1, sep='\t')
table42 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/UP_KW_MOLECULAR_FUNCTION /padj10_RNA-binding_UP_KW_MOLECULAR_FUNCTION.tsv"
path2="Stress_datasets/UP_KW_MOLECULAR_FUNCTION /log2change10_RNA-binding_UP_KW_MOLECULAR_FUNCTION.tsv"
table51 = pd.read_csv(path1, sep='\t')
table52 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/UP_KW_DOMAIN/top10_coiled_coil/padj10_Coiled_coil_UP_KW_DOMAIN.tsv"
path2="Stress_datasets/UP_KW_DOMAIN/top10_coiled_coil/log2change10_Coiled_coil_UP_KW_DOMAIN.tsv"
table61 = pd.read_csv(path1, sep='\t')
table62 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/UP_KW_DOMAIN/top10_Repeat/padj10_Repeat_UP_KW_DOMAIN.tsv"
path2="Stress_datasets/UP_KW_DOMAIN/top10_Repeat/log2change10_Repeat_UP_KW_DOMAIN.tsv"
table71 = pd.read_csv(path1, sep='\t')
table72 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/UP_KW_DOMAIN/top10_Zinc-finger/padj10_Zinc-finger_UP_KW_DOMAIN.tsv"
path2="Stress_datasets/UP_KW_DOMAIN/top10_Zinc-finger/log2change10_Zinc-finger_UP_KW_DOMAIN.tsv"
table81 = pd.read_csv(path1, sep='\t')
table82 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/UP_KW_CELLULAR_COMPONENT/Top10_Cytoplasm/padj10_Cytoplasm_UP_KW_CELLULAR_COMPONENT.tsv"
path2="Stress_datasets/UP_KW_CELLULAR_COMPONENT/Top10_Cytoplasm/log2change10_Cytoplasm_UP_KW_CELLULAR_COMPONENT.tsv"
table91 = pd.read_csv(path1, sep='\t')
table92 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/UP_KW_CELLULAR_COMPONENT/top10_Nucleus/padj10_Nucleus_UP_KW_CELLULAR_COMPONENT.tsv"
path2="Stress_datasets/UP_KW_CELLULAR_COMPONENT/top10_Nucleus/log2change10_Nucleus_UP_KW_CELLULAR_COMPONENT.tsv"
table101 = pd.read_csv(path1, sep='\t')
table102 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_MF_DIRECT/top10_ATP_binding/padj10_ATP_binding_GOTERM_MF_DIRECT.tsv"
path2="Stress_datasets/GOTERM_MF_DIRECT/top10_ATP_binding/log2change10_ATP_binding_GOTERM_MF_DIRECT.tsv"
table111 = pd.read_csv(path1, sep='\t')
table112 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_MF_DIRECT/top10_magnesium_ion_binding/padj10_magnesium_ion_binding_GOTERM_MF_DIRECT.tsv"
path2="Stress_datasets/GOTERM_MF_DIRECT/top10_magnesium_ion_binding/log2change10_magnesium_ion_binding_GOTERM_MF_DIRECT.tsv"
table121 = pd.read_csv(path1, sep='\t')
table122 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_MF_DIRECT/top10_metal_ion_binding/padj10_metal_ion_binding_GOTERM_MF_DIRECT.tsv"
path2="Stress_datasets/GOTERM_MF_DIRECT/top10_metal_ion_binding/log2change10_metal_ion_binding_GOTERM_MF_DIRECT.tsv"
table131 = pd.read_csv(path1, sep='\t')
table132 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_MF_DIRECT/top10_nucleotide_binding/padj10_nucleotide_binding_GOTERM_MF_DIRECT.tsv"
path2="Stress_datasets/GOTERM_MF_DIRECT/top10_nucleotide_binding/log2change10_nucleotide_binding_GOTERM_MF_DIRECT.tsv"
table141 = pd.read_csv(path1, sep='\t')
table142 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_MF_DIRECT/Top10_protein_binding/padj10_protein_binding_stress_granule_GOTERM_MF_DIRECT.tsv"
path2="Stress_datasets/GOTERM_MF_DIRECT/Top10_protein_binding/log2change10_protein_binding_stress_granule_GOTERM_MF_DIRECT.tsv"
table151 = pd.read_csv(path1, sep='\t')
table152 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_MF_DIRECT/top10_RNA_binding/padj10_RNA_binding_GOTERM_MF_DIRECT.tsv"
path2="Stress_datasets/GOTERM_MF_DIRECT/top10_RNA_binding/log2change10_RNA_binding_GOTERM_MF_DIRECT.tsv"
table161 = pd.read_csv(path1, sep='\t')
table162 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_CC_DIRECT/Top10_cytoplasm/padj10_cytoplasm_GOTERM_CC_DIRECT.tsv"
path2="Stress_datasets/GOTERM_CC_DIRECT/Top10_cytoplasm/log2change10_cytoplasm_GOTERM_CC_DIRECT.tsv"
table171 = pd.read_csv(path1, sep='\t')
table172 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_CC_DIRECT/top10_cytoplasmic_stress_granule/padj10_cytoplasmic_stress_granule_GOTERM_CC_DIRECT.tsv"
path2="Stress_datasets/GOTERM_CC_DIRECT/top10_cytoplasmic_stress_granule/log2change10_cytoplasmic_stress_granule_GOTERM_CC_DIRECT.tsv"
table181 = pd.read_csv(path1, sep='\t')
table182 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_CC_DIRECT/Top10_cytosol/padj10_cytosol_GOTERM_CC_DIRECT.tsv"
path2="Stress_datasets/GOTERM_CC_DIRECT/Top10_cytosol/log2change10_cytosol_GOTERM_CC_DIRECT.tsv"
table191 = pd.read_csv(path1, sep='\t')
table192 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_CC_DIRECT/Top10_endosome/padj10_endosome_GOTERM_CC_DIRECT.tsv"
path2="Stress_datasets/GOTERM_CC_DIRECT/Top10_endosome/log2change10_endosome_GOTERM_CC_DIRECT.tsv"
table201 = pd.read_csv(path1, sep='\t')
table202 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_CC_DIRECT/Top10_nucleoplasm/padj10_nucleoplasm_GOTERM_CC_DIRECT.tsv"
path2="Stress_datasets/GOTERM_CC_DIRECT/Top10_nucleoplasm/log2change10_nucleoplasm_GOTERM_CC_DIRECT.tsv"
table211 = pd.read_csv(path1, sep='\t')
table212 = pd.read_csv(path2, sep='\t')

# %%
path1="Stress_datasets/GOTERM_CC_DIRECT/Top10_nucleus/padj10_nucleus_GOTERM_CC_DIRECT.tsv"
path2="Stress_datasets/GOTERM_CC_DIRECT/Top10_nucleus/log2change10_nucleus_GOTERM_CC_DIRECT.tsv"
table221 = pd.read_csv(path1, sep='\t')
table222 = pd.read_csv(path2, sep='\t')

# %%
datasets = [table11, table21, table31, table41, table51, table61, table71, table81, table91, 
            table101, table111, table121, table131, table141, table151, table161, table171, 
            table181, table191, table201, table211, table221]
merged_df= pd.concat(datasets)
merged_df.to_csv('./Stress_datasets/Overall_padj_Top10.tsv', sep='\t', index=False)

# %%
gene_counts = merged_df['Gene_Name'].value_counts().reset_index()
gene_counts.columns = ['Gene_Name', 'Count']
gene_pvalues = merged_df.groupby('Gene_Name')['padj'].mean().reset_index()
gene_counts = pd.merge(gene_counts, gene_pvalues, on='Gene_Name')

gene_urls = merged_df.groupby('Gene_Name')['URL'].first().reset_index() 
gene_counts = pd.merge(gene_counts, gene_urls, on='Gene_Name', how='left')
# Filter genes with count > 1
gene_counts_filtered = gene_counts[gene_counts['Count'] > 3]
gene_counts_filtered.to_csv('./Stress_datasets/OverallTableCount_padj.tsv', sep='\t', index=False)
gene_counts_filtered
# Out:
#    Gene_Name  Count      padj  \
# 0      Nr4a1     13  0.004693
# 1      Hdac7     12  0.011835
# 2       Wee1     11  0.004077
# 3       Rnf4     10  0.003113
# 4      Rbm4b      9  0.011957
# 5      Spry4      9  0.007798
# 6      Xrcc3      9  0.001919
# 7       Egr2      8  0.011957
# 8      Srp68      8  0.011957
# 9        Fos      7  0.011957
# 10     Nup50      7  0.004077
# 11       Aqr      6  0.011957
# 12   Caprin1      5  0.037804
# 13     Mov10      5  0.022969
# 14    Ccdc62      5  0.011957
# 15       Kcp      5  0.001810
# 16      Sbsn      4  0.000793
#
#                                                                                            URL
# 0    https://davidbioinformatics.nih.gov/api.jsp?type=ENTREZ_GENE_ID&ids=15370&tool=geneReport
# 1    https://davidbioinformatics.nih.gov/api.jsp?type=ENTREZ_GENE_ID&ids=56233&tool=geneReport
# 2    https://davidbioinformatics.nih.gov/api.jsp?type=ENTREZ_GENE_ID&ids=22390&tool=geneReport
# ...

# %%
# Normalize and set up color mapping
norm = plt.Normalize(gene_counts_filtered['padj'].min(), gene_counts_filtered['padj'].max())
colors = cm.viridis(norm(gene_counts_filtered['padj']))

# Plot the bar chart with color mapping
fig, ax = plt.subplots(figsize=(10, 6))  # Explicitly create figure and axes
bars = ax.bar(gene_counts_filtered['Gene_Name'], gene_counts_filtered['Count'], color=colors)

# Set labels and title
ax.set_xlabel('Gene Name')
ax.set_ylabel('Count')
ax.set_title('Overall Gene Counts with Padj-value-Based Coloring (Count > 3)')
ax.set_xticks(range(len(gene_counts_filtered['Gene_Name'])))
ax.set_xticklabels(gene_counts_filtered['Gene_Name'], rotation=45, ha='right')

# Set y-axis to only have integer values
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

max_count = gene_counts_filtered['Count'].max()
ax.set_ylim(0, max_count + 0.5)

# Add a colorbar for reference
sm = cm.ScalarMappable(cmap='viridis', norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.2)
cbar.set_label('Adjusted P-value (Padj)')  # Changed label to be more descriptive

# Annotate p-values on bars
for i, pval in enumerate(gene_counts_filtered['padj']):
    ax.text(i, gene_counts_filtered['Count'].iloc[i] + 0.1, f'{pval:.2e}', ha='center', fontsize=8)

plt.tight_layout()
plt.show()

# %%
datasets = [table12, table22, table32, table42, table52, table62, table72, table82, table92, 
            table102, table112, table122, table132, table142, table152, table162, table172, 
            table182, table192, table202, table212, table222]
merged_df= pd.concat(datasets)
merged_df.to_csv('./Stress_datasets/Overall_merge_log2FoldChange_Top10.tsv', sep='\t', index=False)

# %%
gene_counts = merged_df['Gene_Name'].value_counts().reset_index()
gene_counts.columns = ['Gene_Name', 'Count']
gene_pvalues = merged_df.groupby('Gene_Name')['log2FoldChange'].mean().reset_index()
gene_counts = pd.merge(gene_counts, gene_pvalues, on='Gene_Name')

gene_urls = merged_df.groupby('Gene_Name')['URL'].first().reset_index() 
gene_counts = pd.merge(gene_counts, gene_urls, on='Gene_Name', how='left')
# Filter genes with count > 1
gene_counts_filtered = gene_counts[gene_counts['Count'] > 3]
gene_counts_filtered.to_csv('./Stress_datasets/Overall_TableCount_log2FoldChange', sep='\t', index=False)
gene_counts_filtered
# Out:
#    Gene_Name  Count  log2FoldChange  \
# 0      Nr4a1     13        0.432547
# 1      Hdac7     12       -0.256441
# 2       Wee1     11        0.174605
# 3       Rnf4     10        0.105037
# 4      Rbm4b      9       -0.176596
# 5      Spry4      9        0.166831
# 6      Xrcc3      9       -0.289597
# 7       Egr2      8        0.599209
# 8      Srp68      8        0.094842
# 9        Fos      7        0.619911
# 10     Nup50      7        0.080698
# 11       Aqr      6        0.106255
# 12   Caprin1      5        0.092796
# 13     Mov10      5       -0.225631
# 14    Ccdc62      5       -0.292479
# 15       Kcp      5       -0.458202
# 16      Sbsn      4       -0.344124
#
#                                                                                            URL
# 0    https://davidbioinformatics.nih.gov/api.jsp?type=ENTREZ_GENE_ID&ids=15370&tool=geneReport
# 1    https://davidbioinformatics.nih.gov/api.jsp?type=ENTREZ_GENE_ID&ids=56233&tool=geneReport
# ...

# %%
abs_log2FoldChange = gene_counts_filtered['log2FoldChange'].abs()

# Normalize and set up color mapping based on absolute log2FoldChange values
norm = plt.Normalize(abs_log2FoldChange.min(), abs_log2FoldChange.max())
colors = cm.viridis(norm(abs_log2FoldChange))

# Plot the bar chart with color mapping
fig, ax = plt.subplots(figsize=(10, 6))  # Explicitly create figure and axes
bars = ax.bar(gene_counts_filtered['Gene_Name'], gene_counts_filtered['Count'], color=colors)

# Set labels and title
ax.set_xlabel('Gene Name')
ax.set_ylabel('Count')
ax.set_title('Overall Gene Counts with log2FoldChange-Based Coloring (Count > 3)')
ax.set_xticks(range(len(gene_counts_filtered['Gene_Name'])))
ax.set_xticklabels(gene_counts_filtered['Gene_Name'], rotation=45, ha='right')
max_count = gene_counts_filtered['Count'].max()
ax.set_ylim(0, max_count + 0.5) 

# Ensure y-axis only shows integer values
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

# Add a colorbar for reference
sm = cm.ScalarMappable(cmap='viridis', norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.2)
cbar.set_label('Absolute Log2FoldChange Value')  # Changed label to be more descriptive

# Annotate p-values on bars
for i, pval in enumerate(gene_counts_filtered['log2FoldChange']):
    ax.text(i, gene_counts_filtered['Count'].iloc[i] + 0.1, f'{pval:.2e}', ha='center', fontsize=8)

plt.tight_layout()
plt.show()
